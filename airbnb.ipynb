# %%
import pandas as pd

# %%
neighbourhoods = pd.read_csv('neighbourhoods.csv')
neighbourhoods
# Out:
#      neighbourhood_group                neighbourhood
# 0                    NaN               Allied Gardens
# 1                    NaN                   Alta Vista
# 2                    NaN  Amphitheater And Water Park
# 3                    NaN                  Balboa Park
# 4                    NaN                  Bario Logan
# ..                   ...                          ...
# 103                  NaN               Village Center
# 104                  NaN                      Webster
# 105                  NaN      West University Heights
# 106                  NaN                  Wooded Area
# 107                  NaN                  Yosemite Dr
#
# [108 rows x 2 columns]

# %%
neighbourhoods['neighbourhood_group'].unique()
# Out:
# array([nan])

# %%
# neighbourhoods = neighbourhoods.drop(columns=['neighbourhood_group'])
# neighbourhoods

# %%
listings = pd.read_csv('listings.csv')
listings.head()
# Out:
#                    id                                               name  \
# 0            36520775     Casita, Apartment Suite, with private entrance
# 1             8953293                      Pacific Beach Luxury Townhome
# 2  906879006049059257   Massive Oceanview 6BR/6BA Sleeps 30+Rooftop Deck
# 3            35603941                            1 Bedroom living rental
# 4  714055687048273247  SD Lux Home/ Hot tub/ 360 Panoramic views/6 Beds!
#
#      host_id    host_name  neighbourhood_group      neighbourhood   latitude  \
# 0   26696930  Val Anthony                  NaN    Eastlake Vistas  32.639230
# 1   46795717       Hector                  NaN      Pacific Beach  32.798990
# 2  348089487         Kyle                  NaN        Mission Bay  32.772404
# 3   68425727          Moe                  NaN  City Heights East  32.756050
# 4  365311111       Nataly                  NaN        Mission Bay  32.575360
#
# ...

# %%
grouped = listings.groupby('neighbourhood').count().sort_values('id', ascending = False)
grouped
# Out:
#                         id  name  host_id  host_name  neighbourhood_group  \
# neighbourhood
# Mission Bay           1762  1762     1762       1762                    0
# Pacific Beach          971   971      971        971                    0
# La Jolla               813   813      813        813                    0
# Ocean Beach            575   575      575        575                    0
# North Hills            507   507      507        507                    0
# ...                    ...   ...      ...        ...                  ...
# Yosemite Dr              2     2        2          2                    0
# Tijuana River Valley     1     1        1          1                    0
# Eastlake Trails          1     1        1          1                    0
# Eastlake Woods           1     1        1          1                    0
# Estlake Greens           1     1        1          1                    0
#
# ...

# %%
grouped['id'].unique()
# Out:
# array([1762,  971,  813,  575,  507,  497,  455,  326,  303,  231,  212,
#         197,  186,  183,  176,  169,  168,  163,  161,  159,  153,  131,
#         129,  125,  120,  114,  113,  110,  101,  100,   98,   97,   91,
#          80,   75,   67,   66,   65,   58,   52,   51,   50,   46,   44,
#          42,   39,   38,   37,   35,   34,   31,   30,   27,   26,   25,
#          24,   21,   19,   18,   17,   16,   15,   14,   13,   12,    9,
#           8,    7,    6,    5,    4,    3,    2,    1])

# %%
grouped = grouped.reset_index()
grouped
# Out:
#             neighbourhood    id  name  host_id  host_name  \
# 0             Mission Bay  1762  1762     1762       1762
# 1           Pacific Beach   971   971      971        971
# 2                La Jolla   813   813      813        813
# 3             Ocean Beach   575   575      575        575
# 4             North Hills   507   507      507        507
# ..                    ...   ...   ...      ...        ...
# 96            Yosemite Dr     2     2        2          2
# 97   Tijuana River Valley     1     1        1          1
# 98        Eastlake Trails     1     1        1          1
# 99         Eastlake Woods     1     1        1          1
# 100        Estlake Greens     1     1        1          1
#
#      neighbourhood_group  latitude  longitude  room_type  price  \
# 0                      0      1762       1762       1762   1742
# 1                      0       971        971        971    937
# 2                      0       813        813        813    798
# ...

# %%
neighbourhood_count = grouped[['neighbourhood', 'id']]
neighbourhood_count
# Out:
#             neighbourhood    id
# 0             Mission Bay  1762
# 1           Pacific Beach   971
# 2                La Jolla   813
# 3             Ocean Beach   575
# 4             North Hills   507
# ..                    ...   ...
# 96            Yosemite Dr     2
# 97   Tijuana River Valley     1
# 98        Eastlake Trails     1
# 99         Eastlake Woods     1
# 100        Estlake Greens     1
#
# [101 rows x 2 columns]

# %%
# neighbourhood_count.to_csv('neighbourhood_count.csv')

# %%
listings = pd.read_csv('listings.csv')
listings
# Out:
#                         id                                               name  \
# 0                 36520775     Casita, Apartment Suite, with private entrance
# 1                  8953293                      Pacific Beach Luxury Townhome
# 2       906879006049059257   Massive Oceanview 6BR/6BA Sleeps 30+Rooftop Deck
# 3                 35603941                            1 Bedroom living rental
# 4       714055687048273247  SD Lux Home/ Hot tub/ 360 Panoramic views/6 Beds!
# ...                    ...                                                ...
# 11491   791992251762569069      Waterfront Condo w/ AC, BBQ, & Outdoor Living
# 11492  1111860840065102598                   Luxury Penthouse w/Ballpark View
# 11493             49860821  3 Houses to Beach ☆ 2 Fenced Yards ☆ AC ☆ Dogs ok
# 11494   995696965862309622                                    Room in a house
# 11495             43960814  McNoone Properties Harbor Hideaway/with workspace
#
# ...

# %%
detailed_listings = pd.read_csv('detailed_listings.csv')
detailed_listings
# Out:
#                        id                                      listing_url  \
# 0                       6                   https://www.airbnb.com/rooms/6
# 1                   29967               https://www.airbnb.com/rooms/29967
# 2                   54001               https://www.airbnb.com/rooms/54001
# 3                   62274               https://www.airbnb.com/rooms/62274
# 4                   62949               https://www.airbnb.com/rooms/62949
# ...                   ...                                              ...
# 11491  904270218390644646  https://www.airbnb.com/rooms/904270218390644646
# 11492  904276627967513897  https://www.airbnb.com/rooms/904276627967513897
# 11493  904317165657088833  https://www.airbnb.com/rooms/904317165657088833
# 11494  904329543981408158  https://www.airbnb.com/rooms/904329543981408158
# 11495  904345681531743661  https://www.airbnb.com/rooms/904345681531743661
#
#             scrape_id last_scraped       source  \
# ...

# %%
listings
# Out:
#                         id                                               name  \
# 0                 36520775     Casita, Apartment Suite, with private entrance
# 1                  8953293                      Pacific Beach Luxury Townhome
# 2       906879006049059257   Massive Oceanview 6BR/6BA Sleeps 30+Rooftop Deck
# 3                 35603941                            1 Bedroom living rental
# 4       714055687048273247  SD Lux Home/ Hot tub/ 360 Panoramic views/6 Beds!
# ...                    ...                                                ...
# 11491   791992251762569069      Waterfront Condo w/ AC, BBQ, & Outdoor Living
# 11492  1111860840065102598                   Luxury Penthouse w/Ballpark View
# 11493             49860821  3 Houses to Beach ☆ 2 Fenced Yards ☆ AC ☆ Dogs ok
# 11494   995696965862309622                                    Room in a house
# 11495             43960814  McNoone Properties Harbor Hideaway/with workspace
#
# ...

# %%
listings.groupby('neighbourhood')[['id']].count().sort_values("id",ascending = False)
# Out:
#                         id
# neighbourhood
# Mission Bay           1762
# Pacific Beach          971
# La Jolla               813
# Ocean Beach            575
# North Hills            507
# ...                    ...
# Yosemite Dr              2
# Tijuana River Valley     1
# Eastlake Trails          1
# Eastlake Woods           1
# Estlake Greens           1
#
# [101 rows x 1 columns]

# %%
calendar = pd.read_csv('calendar (1).csv.gz', compression = 'gzip', dtype=str)
calendar
# Out:
#                   listing_id        date available    price adjusted_price  \
# 0                          6  2024-03-26         f  $295.00            NaN
# 1                          6  2024-03-27         f  $295.00            NaN
# 2                          6  2024-03-28         f  $295.00            NaN
# 3                          6  2024-03-29         f  $295.00            NaN
# 4                          6  2024-03-30         f  $295.00            NaN
# ...                      ...         ...       ...      ...            ...
# 4195522  1119001430159131999  2025-03-21         f   $60.00            NaN
# 4195523  1119001430159131999  2025-03-22         f   $60.00            NaN
# 4195524  1119001430159131999  2025-03-23         f   $60.00            NaN
# 4195525  1119001430159131999  2025-03-24         f   $60.00            NaN
# 4195526  1119001430159131999  2025-03-25         f   $60.00            NaN
#
#         minimum_nights maximum_nights
# ...

# %%
calendar['date'].unique()
# Out:
# array(['2024-03-26', '2024-03-27', '2024-03-28', '2024-03-29',
#        '2024-03-30', '2024-03-31', '2024-04-01', '2024-04-02',
#        '2024-04-03', '2024-04-04', '2024-04-05', '2024-04-06',
#        '2024-04-07', '2024-04-08', '2024-04-09', '2024-04-10',
#        '2024-04-11', '2024-04-12', '2024-04-13', '2024-04-14',
#        '2024-04-15', '2024-04-16', '2024-04-17', '2024-04-18',
#        '2024-04-19', '2024-04-20', '2024-04-21', '2024-04-22',
#        '2024-04-23', '2024-04-24', '2024-04-25', '2024-04-26',
#        '2024-04-27', '2024-04-28', '2024-04-29', '2024-04-30',
#        '2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04',
#        '2024-05-05', '2024-05-06', '2024-05-07', '2024-05-08',
#        '2024-05-09', '2024-05-10', '2024-05-11', '2024-05-12',
#        '2024-05-13', '2024-05-14', '2024-05-15', '2024-05-16',
#        '2024-05-17', '2024-05-18', '2024-05-19', '2024-05-20',
#        '2024-05-21', '2024-05-22', '2024-05-23', '2024-05-24',
# ...

# %%
calendar['price']
# Out:
# 0          $295.00
# 1          $295.00
# 2          $295.00
# 3          $295.00
# 4          $295.00
#             ...
# 4195522     $60.00
# 4195523     $60.00
# 4195524     $60.00
# 4195525     $60.00
# 4195526     $60.00
# Name: price, Length: 4195527, dtype: object

# %%
grouped
# Out:
#             neighbourhood    id  name  host_id  host_name  \
# 0             Mission Bay  1762  1762     1762       1762
# 1           Pacific Beach   971   971      971        971
# 2                La Jolla   813   813      813        813
# 3             Ocean Beach   575   575      575        575
# 4             North Hills   507   507      507        507
# ..                    ...   ...   ...      ...        ...
# 96            Yosemite Dr     2     2        2          2
# 97   Tijuana River Valley     1     1        1          1
# 98        Eastlake Trails     1     1        1          1
# 99         Eastlake Woods     1     1        1          1
# 100        Estlake Greens     1     1        1          1
#
#      neighbourhood_group  latitude  longitude  room_type  price  \
# 0                      0      1762       1762       1762   1742
# 1                      0       971        971        971    937
# 2                      0       813        813        813    798
# ...

# %%
# grouped = calendar.groupby('id').max()#.reset_index().sort_values('listing_id')
# grouped
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %%
# grouped['listing_id'].astype(int)
# grouped['listing_id'] = grouped['listing_id'].apply(int)

# %%
# grouped.sort_values('listing_id')

# %%
# missing_ids = set(listings['id']) - set(grouped['listing_id'])

# # Extract the missing rows from df1
# missing_rows = listings[listings['id'].isin(missing_ids)]
# missing_rows

# %%
# listings = listings.drop(3568)

# %%
listings
# Out:
#                         id                                               name  \
# 0                 36520775     Casita, Apartment Suite, with private entrance
# 1                  8953293                      Pacific Beach Luxury Townhome
# 2       906879006049059257   Massive Oceanview 6BR/6BA Sleeps 30+Rooftop Deck
# 3                 35603941                            1 Bedroom living rental
# 4       714055687048273247  SD Lux Home/ Hot tub/ 360 Panoramic views/6 Beds!
# ...                    ...                                                ...
# 11491   791992251762569069      Waterfront Condo w/ AC, BBQ, & Outdoor Living
# 11492  1111860840065102598                   Luxury Penthouse w/Ballpark View
# 11493             49860821  3 Houses to Beach ☆ 2 Fenced Yards ☆ AC ☆ Dogs ok
# 11494   995696965862309622                                    Room in a house
# 11495             43960814  McNoone Properties Harbor Hideaway/with workspace
#
# ...

# %%
grouped
# Out:
#             neighbourhood    id  name  host_id  host_name  \
# 0             Mission Bay  1762  1762     1762       1762
# 1           Pacific Beach   971   971      971        971
# 2                La Jolla   813   813      813        813
# 3             Ocean Beach   575   575      575        575
# 4             North Hills   507   507      507        507
# ..                    ...   ...   ...      ...        ...
# 96            Yosemite Dr     2     2        2          2
# 97   Tijuana River Valley     1     1        1          1
# 98        Eastlake Trails     1     1        1          1
# 99         Eastlake Woods     1     1        1          1
# 100        Estlake Greens     1     1        1          1
#
#      neighbourhood_group  latitude  longitude  room_type  price  \
# 0                      0      1762       1762       1762   1742
# 1                      0       971        971        971    937
# 2                      0       813        813        813    798
# ...

# %%
merged_df = pd.merge(listings, grouped, left_on= 'id', right_on = 'id', how = 'left')
merged_df
# Out:
#                         id                                             name_x  \
# 0                 36520775     Casita, Apartment Suite, with private entrance
# 1                  8953293                      Pacific Beach Luxury Townhome
# 2       906879006049059257   Massive Oceanview 6BR/6BA Sleeps 30+Rooftop Deck
# 3                 35603941                            1 Bedroom living rental
# 4       714055687048273247  SD Lux Home/ Hot tub/ 360 Panoramic views/6 Beds!
# ...                    ...                                                ...
# 11492   791992251762569069      Waterfront Condo w/ AC, BBQ, & Outdoor Living
# 11493  1111860840065102598                   Luxury Penthouse w/Ballpark View
# 11494             49860821  3 Houses to Beach ☆ 2 Fenced Yards ☆ AC ☆ Dogs ok
# 11495   995696965862309622                                    Room in a house
# 11496             43960814  McNoone Properties Harbor Hideaway/with workspace
#
# ...

# %%
merged_df.columns
# Out:
# Index(['id', 'name_x', 'host_id_x', 'host_name_x', 'neighbourhood_group_x',
#        'neighbourhood_x', 'latitude_x', 'longitude_x', 'room_type_x',
#        'price_x', 'minimum_nights_x', 'number_of_reviews_x', 'last_review_x',
#        'reviews_per_month_x', 'calculated_host_listings_count_x',
#        'availability_365_x', 'number_of_reviews_ltm_x', 'license_x',
#        'neighbourhood_y', 'name_y', 'host_id_y', 'host_name_y',
#        'neighbourhood_group_y', 'latitude_y', 'longitude_y', 'room_type_y',
#        'price_y', 'minimum_nights_y', 'number_of_reviews_y', 'last_review_y',
#        'reviews_per_month_y', 'calculated_host_listings_count_y',
#        'availability_365_y', 'number_of_reviews_ltm_y', 'license_y'],
#       dtype='object')

# %%
# merged_df['price_y'] = merged_df['price_y'].str.replace('$','').str.replace(',','').apply(float)

# %%
# merged_df.groupby('neighbourhood')['price_y'].lower_quartile()

statistics = merged_df.groupby('neighbourhood').agg({'price_y': ['min', 'max', 'median', lambda x: x.quantile(0.25), lambda x: x.quantile(0.75)]})
statistics.columns = ['min', 'max', 'median', 'lower_quartile', 'upper_quartile']

statistics

# %%
statistics = statistics.reset_index()

# %%
neighbourhoods = ["Mission Bay", "Pacific Beach", "La Jolla", "Ocean Beach", 
                  "North Hills", "East Village", "Midtown", "Loma Portal", 
                  "Gaslamp Quarter", "Balboa Park"]

neighbourhoods_stats = statistics[statistics['neighbourhood'].isin(neighbourhoods)]
neighbourhoods_stats

# %%
neighbourhoods_stats.to_csv('neighbourhoods_stats')

# %%
# listings[['id', 'latitude', 'longitude']]
listings

# %%
# listings.to_json('data.json', orient='records')

# %%
merged_df.columns

# %%
merged_df['month'] = pd.to_datetime(merged_df['date']).dt.month
merged_df['month'].unique()

merged_df['date'].unique()

# %%
merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 merged_df
#
# NameError: name 'merged_df' is not defined

# %%
calendar_grouped = calendar.groupby(['listing_id', 'date'])['available'].max().reset_index()
calendar_grouped
# Out:
#                   listing_id        date available
# 0        1000044065779829923  2024-03-25         f
# 1        1000044065779829923  2024-03-26         t
# 2        1000044065779829923  2024-03-27         f
# 3        1000044065779829923  2024-03-28         f
# 4        1000044065779829923  2024-03-29         f
# ...                      ...         ...       ...
# 4195522   999966711992129597  2025-03-20         f
# 4195523   999966711992129597  2025-03-21         f
# 4195524   999966711992129597  2025-03-22         f
# 4195525   999966711992129597  2025-03-23         f
# 4195526   999966711992129597  2025-03-24         f
#
# [4195527 rows x 3 columns]

# %%
calendar_grouped.to_csv('calendar_grouped')

# %%
calendar

# %%
listing_6 = calendar[calendar['listing_id'] == '6']
listing_6

# %%
listing_6['month'] = pd.to_datetime(listing_6['date']).dt.month
listing_6
# listing_6['available'].value_counts() #false = booked

# %%
listing_6['month'].unique()

# %% [markdown]
# Neighborhood #1
# - 5/31
# - 6/31
# - 28/31
# - 19/31
#     - 15/31 / 4
#
# Neighborhood #2
# - 16/31
# - 20/31
#
#     - 18/31 / 2

# %%
15/31

# %%
18/31

# %%
listings

# %% [markdown]
# ### Occupancy Trend (Heatmap)
# group (x-axis) --> month
#
# variable (y-axis) --> neighborhood
#
# value (count) --> number of Airbnbs booked (value of false for "availability")

# %%
calendar_grouped
# Out:
#                   listing_id        date available
# 0        1000044065779829923  2024-03-25         f
# 1        1000044065779829923  2024-03-26         t
# 2        1000044065779829923  2024-03-27         f
# 3        1000044065779829923  2024-03-28         f
# 4        1000044065779829923  2024-03-29         f
# ...                      ...         ...       ...
# 4195522   999966711992129597  2025-03-20         f
# 4195523   999966711992129597  2025-03-21         f
# 4195524   999966711992129597  2025-03-22         f
# 4195525   999966711992129597  2025-03-23         f
# 4195526   999966711992129597  2025-03-24         f
#
# [4195527 rows x 3 columns]

# %%
calendar_grouped['month'] = pd.to_datetime(calendar_grouped['date']).dt.month
calendar_grouped
# Out:
#                   listing_id        date available  month
# 0        1000044065779829923  2024-03-25         f      3
# 1        1000044065779829923  2024-03-26         t      3
# 2        1000044065779829923  2024-03-27         f      3
# 3        1000044065779829923  2024-03-28         f      3
# 4        1000044065779829923  2024-03-29         f      3
# ...                      ...         ...       ...    ...
# 4195522   999966711992129597  2025-03-20         f      3
# 4195523   999966711992129597  2025-03-21         f      3
# 4195524   999966711992129597  2025-03-22         f      3
# 4195525   999966711992129597  2025-03-23         f      3
# 4195526   999966711992129597  2025-03-24         f      3
#
# [4195527 rows x 4 columns]

# %%
merge_this = listings[['id', 'neighbourhood']]
merge_this
# Out:
#                         id      neighbourhood
# 0                 36520775    Eastlake Vistas
# 1                  8953293      Pacific Beach
# 2       906879006049059257        Mission Bay
# 3                 35603941  City Heights East
# 4       714055687048273247        Mission Bay
# ...                    ...                ...
# 11491   791992251762569069        Mission Bay
# 11492  1111860840065102598       East Village
# 11493             49860821        Mission Bay
# 11494   995696965862309622     Allied Gardens
# 11495             43960814        Mission Bay
#
# [11496 rows x 2 columns]

# %%
calendar_grouped['listing_id'] = calendar_grouped['listing_id'].astype(int)
merge_this['id'] = merge_this['id'].astype(int)
# Out:
# /var/folders/_l/f4zhrz9s7q356_sd74v3cqmm0000gn/T/ipykernel_2259/2146440748.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merge_this['id'] = merge_this['id'].astype(int)

# %%
# calendar_grouped.(merge_this, left_on = 'listing_id', right_on = 'id')

# occupancy_df = pd.merge(calendar_grouped, merge_this, left_on='listing_id', right_on='id', how='outer')

# merged_df = pd.merge(listings, grouped, left_on='id', right_on='listing_id', how='inner')


occupancy_df = pd.merge(calendar_grouped, merge_this, left_on='listing_id', right_on='id', how='left')


occupancy_df
# Out:
#                   listing_id        date available  month  \
# 0        1000044065779829923  2024-03-25         f      3
# 1        1000044065779829923  2024-03-26         t      3
# 2        1000044065779829923  2024-03-27         f      3
# 3        1000044065779829923  2024-03-28         f      3
# 4        1000044065779829923  2024-03-29         f      3
# ...                      ...         ...       ...    ...
# 4195522   999966711992129597  2025-03-20         f      3
# 4195523   999966711992129597  2025-03-21         f      3
# 4195524   999966711992129597  2025-03-22         f      3
# 4195525   999966711992129597  2025-03-23         f      3
# 4195526   999966711992129597  2025-03-24         f      3
#
#                           id neighbourhood
# 0        1000044065779829923   Wooded Area
# 1        1000044065779829923   Wooded Area
# 2        1000044065779829923   Wooded Area
# 3        1000044065779829923   Wooded Area
# 4        1000044065779829923   Wooded Area
# ...

# %%
# occupancy_df.to_csv('occupancy_df.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 occupancy_df.to_csv('occupancy_df.csv')
#
# NameError: name 'occupancy_df' is not defined

# %%
occupancy_df.groupby('neighbourhood').count()

# %%
# # Step 1: Convert 'available' column to boolean (False for booked, True for available)
# occupancy_df['available'] = occupancy_df['available'].map({'t': True, 'f': False})

# # Step 2: Calculate the number of bookings (False -> booked, True -> available)
# occupancy_df['booked'] = ~occupancy_df['available']

# # Step 3: Group by 'month' and 'neighborhood' and calculate the average number of bookings
# heatmap_df = occupancy_df.groupby(['month', 'neighbourhood'])['booked'].mean().reset_index()

# heatmap_df

# %%
desired_neighborhoods = [
    'Mission Bay', 'Pacific Beach', 'La Jolla', 'Ocean Beach', 'North Hills',
    'East Village', 'Midtown', 'Loma Portal', 'Gaslamp Quarter', 'Balboa Park'
]
filtered_df = occupancy_df[occupancy_df['neighbourhood'].isin(desired_neighborhoods)]
heatmap_df = filtered_df.groupby(['month', 'neighbourhood'])['booked'].mean().reset_index()

# Step 5: Rename columns to match desired format
heatmap_df.columns = ['group', 'variable', 'value']
heatmap_df

# %%
# heatmap_df.to_csv('heatmap_df.csv')

# %% [markdown]
# # POSSIBLY START HERE

# %%
import pandas as pd
import numpy as np

# %%
# heatmap = pd.read_csv('heatmap.csv')

# %%
heatmap

# %%
# heatmap['value'] = heatmap['value']*100
# heatmap.drop(co,lumns = 'Unnamed: 0')
heatmap
# heatmap.columns

# %%
heatmap = heatmap.drop(columns = 'Unnamed: 0')

heatmap

# %%
heatmap['value'] = np.floor(heatmap['value'])
heatmap

# %%
# heatmap.to_csv('heatmap.csv')

# %%
# heatmap['value'] = heatmap['value']/

# %% [markdown]
# # START HERE FOR HEATMAP CODE

# %%
occupancy = pd.read_csv('occupancy_df.csv')

# %%
occupancy
# Out:
#          Unnamed: 0           listing_id        date available  month  \
# 0                 0  1000044065779829923  2024-03-25         f      3
# 1                 1  1000044065779829923  2024-03-26         t      3
# 2                 2  1000044065779829923  2024-03-27         f      3
# 3                 3  1000044065779829923  2024-03-28         f      3
# 4                 4  1000044065779829923  2024-03-29         f      3
# ...             ...                  ...         ...       ...    ...
# 4195522     4195522   999966711992129597  2025-03-20         f      3
# 4195523     4195523   999966711992129597  2025-03-21         f      3
# 4195524     4195524   999966711992129597  2025-03-22         f      3
# 4195525     4195525   999966711992129597  2025-03-23         f      3
# 4195526     4195526   999966711992129597  2025-03-24         f      3
#
#                           id neighbourhood
# 0        1000044065779829923   Wooded Area
# ...

# %%
occupancy['month'].value_counts().sort_values()
# Out:
# month
# 2     321860
# 4     344850
# 6     344850
# 9     344850
# 11    344850
# 3     356197
# 5     356345
# 7     356345
# 8     356345
# 10    356345
# 12    356345
# 1     356345
# Name: count, dtype: int64

# %%
# occupancy.groupby('month').mean()

# %%
occupancy.groupby(['month','available']).max()
# Out:
#                  Unnamed: 0           listing_id        date  \
# month available
# 1     f             4195474  1119001430159131999  2025-01-31
#       t             4194379  1117864142795026286  2025-01-31
# 2     f             4195502  1119001430159131999  2025-02-28
#       t             4194407  1117864142795026286  2025-02-28
# 3     f             4195526  1119001430159131999  2025-03-25
#       t             4195168  1119001430159131999  2025-03-25
# 4     f             4195181  1118936291797417362  2024-04-30
#       t             4195198  1119001430159131999  2024-04-30
# 5     f             4195218  1118752504163779132  2024-05-31
#       t             4195229  1119001430159131999  2024-05-31
# 6     f             4195256  1118807494219691403  2024-06-30
#       t             4195259  1119001430159131999  2024-06-30
# 7     f             4195290  1118956344229010931  2024-07-31
#       t             4195263  1119001430159131999  2024-07-31
# ...

# %%
neighborhoods = [
    'Mission Bay', 'Pacific Beach', 'La Jolla', 'Ocean Beach', 
    'North Hills', 'East Village', 'Midtown', 'Loma Portal', 
    'Gaslamp Quarter', 'Balboa Park'
]

# Filter the DataFrame for the specified neighborhoods and unavailable listings
filtered_df = occupancy[(occupancy['neighbourhood'].isin(neighborhoods)) & (occupancy['available'] == 'f')]

# Group by month and neighbourhood, then count the occurrences
grouped_df = filtered_df.groupby(['month', 'neighbourhood']).size().reset_index(name='count')

# Rename columns to match the desired format
grouped_df.columns = ['group', 'variable', 'value']
grouped_df
# Out:
#      group         variable  value
# 0        1      Balboa Park   4379
# 1        1     East Village   8951
# 2        1  Gaslamp Quarter   5545
# 3        1         La Jolla  11347
# 4        1      Loma Portal   5646
# ..     ...              ...    ...
# 115     12          Midtown   7173
# 116     12      Mission Bay  18337
# 117     12      North Hills   9006
# 118     12      Ocean Beach   8203
# 119     12    Pacific Beach  11661
#
# [120 rows x 3 columns]

# %%
grouped_df[grouped_df['variable'] == 'Balboa Park']
# Out:
#      group     variable  value
# 0        1  Balboa Park   4379
# 10       2  Balboa Park   4029
# 20       3  Balboa Park   4596
# 30       4  Balboa Park   2931
# 40       5  Balboa Park   1879
# 50       6  Balboa Park   2035
# 60       7  Balboa Park   2553
# 70       8  Balboa Park   2017
# 80       9  Balboa Park   2248
# 90      10  Balboa Park   3025
# 100     11  Balboa Park   3073
# 110     12  Balboa Park   3481

# %% [markdown]
# value --> number of nights booked
#
# why is there more nights booked during the non-summer months?

# %%
calendar = pd.read_csv('calendar (1).csv.gz', compression = 'gzip', dtype=str)
calendar
# Out:
#                   listing_id        date available    price adjusted_price  \
# 0                          6  2024-03-26         f  $295.00            NaN
# 1                          6  2024-03-27         f  $295.00            NaN
# 2                          6  2024-03-28         f  $295.00            NaN
# 3                          6  2024-03-29         f  $295.00            NaN
# 4                          6  2024-03-30         f  $295.00            NaN
# ...                      ...         ...       ...      ...            ...
# 4195522  1119001430159131999  2025-03-21         f   $60.00            NaN
# 4195523  1119001430159131999  2025-03-22         f   $60.00            NaN
# 4195524  1119001430159131999  2025-03-23         f   $60.00            NaN
# 4195525  1119001430159131999  2025-03-24         f   $60.00            NaN
# 4195526  1119001430159131999  2025-03-25         f   $60.00            NaN
#
#         minimum_nights maximum_nights
# ...

# %%
calendar['month'] = pd.to_datetime(calendar['date']).dt.month
calendar
# Out:
#                   listing_id        date available    price adjusted_price  \
# 0                          6  2024-03-26         f  $295.00            NaN
# 1                          6  2024-03-27         f  $295.00            NaN
# 2                          6  2024-03-28         f  $295.00            NaN
# 3                          6  2024-03-29         f  $295.00            NaN
# 4                          6  2024-03-30         f  $295.00            NaN
# ...                      ...         ...       ...      ...            ...
# 4195522  1119001430159131999  2025-03-21         f   $60.00            NaN
# 4195523  1119001430159131999  2025-03-22         f   $60.00            NaN
# 4195524  1119001430159131999  2025-03-23         f   $60.00            NaN
# 4195525  1119001430159131999  2025-03-24         f   $60.00            NaN
# 4195526  1119001430159131999  2025-03-25         f   $60.00            NaN
#
#         minimum_nights maximum_nights  month
# ...

# %%
check = calendar[calendar['available'] == 't']
# calendar = pd.to_datetime(calendar['date'])


# calendar['month'] = calendar['date'].dt.month
check
# Out:
#                   listing_id        date available    price adjusted_price  \
# 111                        6  2024-07-15         t  $295.00            NaN
# 112                        6  2024-07-16         t  $295.00            NaN
# 113                        6  2024-07-17         t  $295.00            NaN
# 114                        6  2024-07-18         t  $295.00            NaN
# 117                        6  2024-07-21         t  $295.00            NaN
# ...                      ...         ...       ...      ...            ...
# 4195426  1119001430159131999  2024-12-15         t   $60.00            NaN
# 4195427  1119001430159131999  2024-12-16         t   $60.00            NaN
# 4195428  1119001430159131999  2024-12-17         t   $60.00            NaN
# 4195429  1119001430159131999  2024-12-18         t   $60.00            NaN
# 4195430  1119001430159131999  2024-12-19         t   $60.00            NaN
#
#         minimum_nights maximum_nights  month
# ...

# %%
grrrr = calendar[calendar['available'] == 'f']
grrrr
# Out:
#                   listing_id        date available    price adjusted_price  \
# 0                          6  2024-03-26         f  $295.00            NaN
# 1                          6  2024-03-27         f  $295.00            NaN
# 2                          6  2024-03-28         f  $295.00            NaN
# 3                          6  2024-03-29         f  $295.00            NaN
# 4                          6  2024-03-30         f  $295.00            NaN
# ...                      ...         ...       ...      ...            ...
# 4195522  1119001430159131999  2025-03-21         f   $60.00            NaN
# 4195523  1119001430159131999  2025-03-22         f   $60.00            NaN
# 4195524  1119001430159131999  2025-03-23         f   $60.00            NaN
# 4195525  1119001430159131999  2025-03-24         f   $60.00            NaN
# 4195526  1119001430159131999  2025-03-25         f   $60.00            NaN
#
#         minimum_nights maximum_nights  month
# ...

# %%
grr_df = filtered_df.groupby(['month', 'neighbourhood']).size().reset_index(name='count')
grr_df
# Out:
#      month    neighbourhood  count
# 0        1      Balboa Park   4379
# 1        1     East Village   8951
# 2        1  Gaslamp Quarter   5545
# 3        1         La Jolla  11347
# 4        1      Loma Portal   5646
# ..     ...              ...    ...
# 115     12          Midtown   7173
# 116     12      Mission Bay  18337
# 117     12      North Hills   9006
# 118     12      Ocean Beach   8203
# 119     12    Pacific Beach  11661
#
# [120 rows x 3 columns]

# %%
grr_df[grr_df['neighbourhood'] == 'Balboa Park']
# Out:
#      month neighbourhood  count
# 0        1   Balboa Park   2782
# 10       2   Balboa Park   2439
# 20       3   Balboa Park   2565
# 30       4   Balboa Park   3999
# 40       5   Balboa Park   5282
# 50       6   Balboa Park   4895
# 60       7   Balboa Park   4608
# 70       8   Balboa Park   5144
# 80       9   Balboa Park   4682
# 90      10   Balboa Park   4136
# 100     11   Balboa Park   3857
# 110     12   Balboa Park   3680

# %%
grr_df.columns = ['group', 'variable', 'value']
heatmap_data = grr_df

# %%
# heatmap_data
# heatmap_data.to_csv('heatmap_data')

# %%
grr_df
# Out:
#      month    neighbourhood  count
# 0        1      Balboa Park   4379
# 1        1     East Village   8951
# 2        1  Gaslamp Quarter   5545
# 3        1         La Jolla  11347
# 4        1      Loma Portal   5646
# ..     ...              ...    ...
# 115     12          Midtown   7173
# 116     12      Mission Bay  18337
# 117     12      North Hills   9006
# 118     12      Ocean Beach   8203
# 119     12    Pacific Beach  11661
#
# [120 rows x 3 columns]

# %%
heatmap_data
# Out:
#      group         variable  value
# 0        1      Balboa Park   2782
# 1        1     East Village   6456
# 2        1  Gaslamp Quarter   3848
# 3        1         La Jolla  13856
# 4        1      Loma Portal   4460
# ..     ...              ...    ...
# 115     12          Midtown   6932
# 116     12      Mission Bay  36285
# 117     12      North Hills   6711
# 118     12      Ocean Beach   9622
# 119     12    Pacific Beach  18440
#
# [120 rows x 3 columns]
